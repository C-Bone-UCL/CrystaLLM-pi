# %% [markdown]
# ## Losses analysis (for appendices of paper)

# %%
import __init__
from _utils._notebook_utils.y_losses_utils import plot_losses

pretrained_model_losses = "model_ckpts/mpdb-small-base-lematerial/checkpoint-1245000/losses.json"
finetuned_models_losses = [
    "model_ckpts/pretraining_benefits/mpdb_2prop_ft/raw/checkpoint-50000/losses.json",
    "model_ckpts/pretraining_benefits/mpdb_2prop_ft/slider/checkpoint-18500/losses.json",
    "model_ckpts/pretraining_benefits/mpdb_2prop_ft/prepend/checkpoint-21000/losses.json",
    "model_ckpts/pretraining_benefits/mpdb_2prop_ft/PKV/checkpoint-27500/losses.json",
] 
output_path = "plots/losses.png"

plot_losses(
    pretrained_model_losses,
    finetuned_models_losses,
    output_path,
    window=5000,
    ymin=0.20,
    ymax=0.85,
    figsize=(8, 6),
    label_fontsize=18,
    ticks_fontsize=16,
    legend_fontsize=16,
    line_width=2.5,
    axes_linewidth=1.5,
    num_xticks=4,
    num_yticks=4
)

# %%
from _utils._notebook_utils.y_losses_utils import plot_component_losses

losses_path = "model_ckpts/mp_20_pxrd_scratch/slider_opt/checkpoint-9500/losses.json"
output_path = "plots/format_losses.png"

plot_component_losses(
    losses_path,
    output_path,
    figsize=(8, 6),
    label_fontsize=18,
    ticks_fontsize=16,
    legend_fontsize=16,
    line_width=2.5,
    axes_linewidth=1.5,
    num_xticks=4,
    num_yticks=4,
    ymax=4
    )

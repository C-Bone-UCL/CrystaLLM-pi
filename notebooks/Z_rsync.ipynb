# %%
# %%bash
#
# rsync -avzu --progress \
#     --exclude '.git/' \
#     --exclude 'wandb/' \
#     --exclude 'HF-databases/' \
#     --exclude 'HuggingFace_DBs/' \
#     --exclude 'config_files/' \
#     --exclude 'model_evaluation/evaluation_files/benchmark/' \
#     --exclude 'crystallmv2.sif' \
#     --exclude '_utils/_evaluation/evaluation_files/' \
#     --exclude '_utils/_evaluation/alignn_model_ckpts/' \
#     --exclude '_models/__pycache__/' \
#     --exclude '__pycache__/' \
#     --exclude '_utils/_evaluation_conditional/__pycache__/' \
#     --exclude '_utils/_evaluation_conditional/mpdb_plots/' \
#     --exclude '_config_files/' \
#     --exclude 'HF-cif-tokenizer/' \
#     --exclude '_utils/_evaluation_og/benchmark/' \
#     --exclude 'optuna_hpsearch_cllmv2.db' \
#     --exclude '_utils/_evaluation_conditional/alignn_model_ckpts/' \
#     --exclude 'model_ckpts/mpdb-2PKV-packed-scratch/.cache/' \
#     --exclude 'model_ckpts/mpdb-2prepend-packed-scratch/.cache/' \
#     --exclude 'model_ckpts/mpdb-2PKV-packed-scratch/.cache/' \
#     --exclude 'model_ckpts/mpdb-2slider-packed-scratch/.cache/' \
#     --exclude 'model_ckpts/mpdb-prepend-packed-scratch/.cache/' \
#     --exclude 'model_ckpts/mpdb-PKV-packed-scratch/.cache/' \
#     --exclude 'model_ckpts/mpdb-slider-packed-scratch/.cache/' \
#     --exclude 'model_ckpts/mpdb-slider-packed-scratch-2/.cache/' \
#     --exclude 'model_ckpts/mpdb-slider-pad-scratch/.cache/' \
#     --exclude 'model_ckpts/mpdb-slider-pad-scratch-2/.cache/' \
#     --exclude 'model_ckpts/mpdb-small-base-lematerial/' \
#     --exclude 'model_ckpts/' \
#     --exclude '_utils/_evaluation_conditional/evaluation_files/' \
#     --exclude '_utils/_evaluation_og/generation_files/' \
#     -e "ssh -i ~/.ssh/exported-keyfile-from-putty-np -o ProxyJump=gateway" \
#     /home/uccacbo/CrystaLLMv2_PKV/ uccacbo@myriad.rc.ucl.ac.uk:/home/uccacbo/Scratch/CrystaLLMv2_PKV/
# Out:
#  ------------------------------------------------------------------------
#  Information Systems - Information Services Division - UCL
#
#  Access to and use of this system are restricted to authorised individuals
#  and subject to UCL Computing Regulations.
#  ------------------------------------------------------------------------
# sending incremental file list
# ./
# .gitignore
#             345 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=77/79)
# None
#          35,798 100%   34.14MB/s    0:00:00 (xfr#2, to-chk=74/79)
# _args.py
#           8,667 100%    8.27MB/s    0:00:00  s    0:00:00 (xfr#3, to-chk=71/79)
# _dataloader.py
#          35,745 100%   34.09MB/s    0:00:00 (xfr#4, to-chk=70/79)
# _hp-search.py
#          11,986 100%    5.85MB/s    0:00:00  72MB/s    0:00:00 (xfr#5, to-chk=69/79)
# _multi-runs.py
#           2,607 100%    1.24MB/s    0:00:00 (xfr#6, to-chk=68/79)
# _train.py
#          12,727 100%    6.07MB/s    0:00:00 (xfr#7, to-chk=66/79)
# dataset_data_range
# ...

# %%
# %%bash
#
# rsync -avzu --dry-run --progress \
#     --exclude 'wandb/' \
#     /home/cyprien/CrystaLLMv2_PKV/ uccacbo@myriad.rc.ucl.ac.uk:/home/uccacbo/Scratch/CrystaLLMv2_PKV/
# Out:
# Error while terminating subprocess (pid=470489):
# rsync error: received SIGINT, SIGTERM, or SIGHUP (code 20) at rsync.c(716) [Receiver=3.2.7]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', "\nrsync -avzu --dry-run --progress \\\n    --exclude 'wandb/' \\\n    uccacbo@myriad.rc.ucl.ac.uk:/home/uccacbo/Scratch/CrystaLLMv2_PKV/_utils/_evaluation_conditional/evaluation_files/ /home/cyprien/CrystaLLMv2_PKV/_utils/_evaluation_conditional/evaluation_files/\n")
#
# File ~/miniconda3/envs/crystallmv2_venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
# ...

# %%
# %%bash
#
# rsync -avzu --dry-run --progress \
#     --exclude 'wandb/' \
#     uccacbo@myriad.rc.ucl.ac.uk:/home/uccacbo/Scratch/DFT-Screen/vasp_outputs/20250804_054625/ /home/cyprien/CrystaLLMv2_PKV/_utils/_evaluation_conditional/dft_results/

# %%
# %%bash
#
# rsync -avzu --dry-run --progress \
#     --exclude 'wandb/' \
#     /home/cyprien/CrystaLLMv2_PKV/ uccacbo@young.rc.ucl.ac.uk:/home/uccacbo/Scratch/CrystaLLMv2_PKV/

# %%
# %%bash
# rsync -avz --delete --progress \
#     --exclude-from '/home/uccacbo/CrystaLLMv2/.exclude-rsync.txt' \
#     -e "ssh -i ~/.ssh/exported-keyfile-from-putty-np -o ProxyJump=gateway" \
#     cyprien@nico.chem.ucl.ac.uk:/home/cyprien/CrystaLLMv2_PKV/ /home/uccacbo/CrystaLLMv2/
# Out:
#  ------------------------------------------------------------------------
#  Information Systems - Information Services Division - UCL
#
#  Access to and use of this system are restricted to authorised individuals
#  and subject to UCL Computing Regulations.
#  ------------------------------------------------------------------------
# receiving incremental file list
# deleting mp-20-data/valid.pt
# deleting mp-20-data/train.pt
# deleting mp-20-data/test.pt
# deleting mp-20-data/
# deleting _config_files/cg_train/mattergen_XRD-slider.jsonc
# deleting _config_files/cg_train/jarvis_XRD-slider.jsonc
# deleting notebooks/X_XRD_JARVIS.ipynb
# deleting notebooks/X_XRD_COD.ipynb
# deleting notebooks/X_XRD_Amil.ipynb
# deleting notebooks/X_TiO2.ipynb
# deleting notebooks/X_SiO2.ipynb
# ./
# .exclude-rsync.txt
#             242 100%  236.33kB/s    0:00:00 (xfr#1, to-chk=180/182)
# .gitignore
#             360 100%  351.56kB/s    0:00:00 (xfr#2, to-chk=179/182)
# _args.py
# ...

# %%
import __init__
# Out:
# Navigated to package root: /home/uccacbo/CrystaLLMv2
# Added package root to Python path

# %%
# %%bash
# rsync -avz --progress \
#     --exclude-from '/home/uccacbo/CrystaLLMv2/.exclude-rsync.txt' \
#     -e "ssh -i ~/.ssh/exported-keyfile-from-putty-np -o ProxyJump=gateway" \
#     mp-20-data/ cyprien@nico.chem.ucl.ac.uk:/home/cyprien/Data_Gen/mp-20-data/
# Out:
#  ------------------------------------------------------------------------
#  Information Systems - Information Services Division - UCL
#
#  Access to and use of this system are restricted to authorised individuals
#  and subject to UCL Computing Regulations.
#  ------------------------------------------------------------------------
# sending incremental file list
# ./
# test.pt
#     780,607,023 100%   23.60MB/s    0:00:31 (xfr#1, to-chk=2/4)
# train.pt
#   2,343,414,511 100%   23.90MB/s    0:01:33 (xfr#2, to-chk=1/4)
# valid.pt
#     781,014,255 100%   22.63MB/s    0:00:32 (xfr#3, to-chk=0/4)
#
# sent 2,666,008,340 bytes  received 76 bytes  16,820,242.37 bytes/sec
# total size is 3,905,035,789  speedup is 1.46

# %%
import os
import pickle as pkl
import numpy as np
import pandas as pd
import joblib

# set new path
os.chdir('/home/cyprien/CrystaLLMv2_PKV')

# %% [markdown]
# Todo:
#
# - Show the various datasets, show how you can train, then show what the test set is, and generation etc.

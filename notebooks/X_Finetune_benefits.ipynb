# %%
import os
import pickle as pkl
import numpy as np
import pandas as pd
import joblib

# set new path
os.chdir('/home/cyprien/CrystaLLMv2_PKV')

# %% [markdown]
# Todo:
# - Show what datasets I use, generations, how I got results etc.
